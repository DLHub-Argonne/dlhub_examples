# %% [markdown]
# <img src="./img/citation.png" width=70%>

# %% [markdown]
# ## Loading the Data
# Run the command `git submodule update --init --recursive`

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
# real_intens_test=np.load('test_data/real_intens_test.npy') #Ground truth object
# real_phase_test=np.load('test_data/real_phase_test.npy') #Ground truth phase
# real_phase_test=real_phase_test*2*np.pi-np.pi #Map the phases back to -pi to pi range
ft_test=np.load('./CDI_NN/test_data/ft_test.npy') #Test diffraction data

# %% [markdown]
# # Plotting Helpers

# %%
# %matplotlib inline
plt.style.use('seaborn-white')
matplotlib.rc('xtick', labelsize=15) 
matplotlib.rc('ytick', labelsize=15)
matplotlib.rc('font',family='Times New Roman')
matplotlib.rcParams['font.size'] = 15
plt.viridis()

from matplotlib import ticker
tick_locator = ticker.MaxNLocator(nbins=3)

def make_cherukara_plot(X, intensities, phases, n_show=3, offset=0):
    fig_size = (12,12)
    h,w = 32,32

    f, axs = plt.subplots(n_show, 3, figsize=fig_size)
    for i in range(0,n_show):
        make_window(np.log10(X[i+offset]).reshape(h,w), axs[i,0])
        make_window(intensities[i+offset].reshape(h,w), axs[i,1])
        make_window(phases[i+offset].reshape(h,w), axs[i,2])
        
    axs[0,0].set_title("Diffraction Pattern")
    axs[0,1].set_title("Structure (Pred)")
    axs[0,2].set_title("Phase (Pred)")
    
def make_window(data, ax):
    im = ax.imshow(data)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    cb=plt.colorbar(im, ax=ax)
    cb.locator = tick_locator
    cb.update_ticks()

# %%
from dlhub_sdk.client import DLHubClient

# Instantiate the DLHub client and find the model IDs
dl = DLHubClient()
structure_model = "mschwarting_anl/cherukara_structure"
phase_model = "mschwarting_anl/cherukara_phase"

# Load testing data
n_test = 10
intensity_threshold = 0.2
X = ft_test[0:n_test].tolist()

# Call to DLHub to get predictions
intensities = np.asarray(dl.run(structure_model, X))
phases = np.asarray(dl.run(phase_model, X))*2*np.pi-np.pi

# %%
make_cherukara_plot(X, intensities, phases, n_show=n_test)

# %%
dl.describe_servable("mschwarting_anl/cherukara_structure")
# Out:
# {'datacite': {'alternateIdentifiers': [{'alternateIdentifier': 'https://github.com/mcherukara/CDI_NN',
#     'alternateIdentifierType': 'URL'}],
#   'creators': [{'affiliations': 'Argonne National Laboratory',
#     'familyName': 'Cherukara',
#     'givenName': 'Mathew J'},
#    {'affiliations': 'Argonne National Laboratory',
#     'familyName': 'Nashed',
#     'givenName': 'Youssef SG'},
#    {'affiliations': 'Argonne National Laboratory',
#     'familyName': 'Harder',
#     'givenName': 'Ross J'}],
#   'identifier': {'identifier': '10.YET/UNASSIGNED', 'identifierType': 'DOI'},
#   'publicationYear': '2019',
#   'publisher': 'DLHub',
#   'relatedIdentifiers': [{'relatedIdentifier': '10.1038/s41598-018-34525-1',
#     'relatedIdentifierType': 'DOI',
#     'relationType': 'IsDescribedBy'},
#    {'relatedIdentifier': 'globus:iDnjbEKilPqn',
#     'relatedIdentifierType': 'Globus',
#     'relationType': 'IsDescribedBy'}],
#   'resourceType': {'resourceTypeGeneral': 'InteractiveResource'},
#   'titles': [{'title': 'Coherent Diffraction Structure Prediction'}]},
#  'dlhub': {'build_location': '/mnt/dlhub_ingest/208a0f88-b197-4782-9cc4-a62319da973f-1566334417',
#   'dependencies': {'python': {'h5py': '2.9.0',
#     'keras': '2.2.4',
#     'tensorflow': '1.14.0'}},
#   'domains': ['materials science'],
#   'ecr_arn': 'arn:aws:ecr:us-east-1:039706667969:repository/208a0f88-b197-4782-9cc4-a62319da973f',
#   'ecr_uri': '039706667969.dkr.ecr.us-east-1.amazonaws.com/208a0f88-b197-4782-9cc4-a62319da973f',
#   'files': {'model': 'structure_weights.hdf5'},
#   'funcx_id': '8d4fdfc7-53c1-49d4-adf0-65e13c6b6815',
#   'id': '208a0f88-b197-4782-9cc4-a62319da973f',
#   'identifier': 'globus:iDnjbEKilPqn',
#   'name': 'cherukara_structure',
#   'owner': 'mschwarting_anl',
#   'publication_date': '1566334345073',
#   'shorthand_name': 'mschwarting_anl/cherukara_structure',
#   'transfer_method': {'POST': 'file', 'path': '/mnt/tmp/servable.zip'},
#   'type': 'servable',
#   'user_id': '5',
#   'version': '0.8.2',
#   'visible_to': ['public']},
#  'servable': {'methods': {'run': {'input': {'description': 'Fourier transformed diffraction intensity',
#      'shape': ['None', '32', '32', '1'],
#      'type': 'ndarray'},
#     'method_details': {'classes': ['output structure image'],
#      'method_name': 'predict'},
#     'output': {'description': 'Output structure image',
#      'shape': ['None', '32', '32', '1'],
#      'type': 'ndarray'}}},
#   'model_summary': '_________________________________________________________________\nLayer (type)                 Output Shape              Param #   \n=================================================================\ninput_1 (InputLayer)         (None, 32, 32, 1)         0         \n_________________________________________________________________\nconv2d_1 (Conv2D)            (None, 32, 32, 32)        320       \n_________________________________________________________________\nconv2d_2 (Conv2D)            (None, 32, 32, 32)        9248      \n_________________________________________________________________\nmax_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0         \n_________________________________________________________________\nconv2d_3 (Conv2D)            (None, 16, 16, 64)        18496     \n_________________________________________________________________\nconv2d_4 (Conv2D)            (None, 16, 16, 64)        36928     \n_________________________________________________________________\nmax_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0         \n_________________________________________________________________\nconv2d_5 (Conv2D)            (None, 8, 8, 128)         73856     \n_________________________________________________________________\nconv2d_6 (Conv2D)            (None, 8, 8, 128)         147584    \n_________________________________________________________________\nmax_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0         \n_________________________________________________________________\nconv2d_7 (Conv2D)            (None, 4, 4, 128)         147584    \n_________________________________________________________________\nconv2d_8 (Conv2D)            (None, 4, 4, 128)         147584    \n_________________________________________________________________\nup_sampling2d_1 (UpSampling2 (None, 8, 8, 128)         0         \n_________________________________________________________________\nconv2d_9 (Conv2D)            (None, 8, 8, 64)          73792     \n_________________________________________________________________\nconv2d_10 (Conv2D)           (None, 8, 8, 64)          36928     \n_________________________________________________________________\nup_sampling2d_2 (UpSampling2 (None, 16, 16, 64)        0         \n_________________________________________________________________\nconv2d_11 (Conv2D)           (None, 16, 16, 32)        18464     \n_________________________________________________________________\nconv2d_12 (Conv2D)           (None, 16, 16, 32)        9248      \n_________________________________________________________________\nup_sampling2d_3 (UpSampling2 (None, 32, 32, 32)        0         \n_________________________________________________________________\nconv2d_13 (Conv2D)           (None, 32, 32, 1)         289       \n=================================================================\nTotal params: 720,321\nTrainable params: 720,321\nNon-trainable params: 0\n_________________________________________________________________\n',
#   'model_type': 'Deep NN',
#   'shim': 'keras.KerasServable',
#   'type': 'Keras Model'}}
