# %% [markdown]
# # Notebook showing DLHub SDK Search Capabilities
#
# A Web UI to this search functionality is available at <a href="https://petreldata.net">Petrel Data</a>

# %%
from dlhub_sdk import DLHubClient

# %%
dl = DLHubClient()

# %% [markdown]
# # List Servables in ~Human Readable Format

# %%
dl.list_servables()
# Out:
# ['akoripelly_gmail/semCNN',
#  'akoripelly_gmail/SEM_CNN_Model',
#  'akoripelly_gmail/SEM',
#  'akoripelly_gmail/neural_network',
#  'akoripelly_gmail/FileLength',
#  'akoripelly_gmail/CNNModel',
#  'akoripelly_gmail/braincountTF',
#  'akoripelly_gmail/brainCNN',
#  'blaiszik_globusid/mnist_tiny_example',
#  'blaiszik_globusid/iris_svm',
#  'blaiszik_globusid/cherukara_phase',
#  'chenru_xsede/static_classifier_geo',
#  'dlhub.test_gmail/1d_norm',
#  'etruelove_uchicago/FileLength',
#  'loganw_globusid/tomo_test',
#  'loganw_globusid/mnist_example',
#  'loganw_globusid/g4mp2_delta_schnet',
#  'loganw_globusid/g4mp2_delta_fchl',
#  'loganw_globusid/candle_p1_combo_demo1',
#  'lzhengchun_globusid/TomoGAN',
#  'maxtuecke_gmail/test_servable_upload',
#  'maxtuecke_gmail/galaxy_image_classifier',
#  'mschwarting_anl/Thin_Films_BG_RF',
#  'mschwarting_anl/Thin_Film_Autoencoder',
#  'mschwarting_anl/mnist',
#  'mschwarting_anl/galaxy_catalog_des',
#  'mschwarting_anl/FileLength',
# ...

# %% [markdown]
# # Search by Owner

# %%
len(dl.search_by_servable(owner="blaiszik_globusid"))
# Out:
# 3

# %% [markdown]
# # Full Text Search All Fields

# %%
dl.search("astronomy")
# Out:
# [{'datacite': {'alternateIdentifiers': [{'alternateIdentifier': 'https://github.com/rhnvrm/galaxy-image-classifier-tensorflow',
#      'alternateIdentifierType': 'URL'}],
#    'creators': [{'affiliations': ['Globus'],
#      'familyName': 'Tuecke',
#      'givenName': 'Max'}],
#    'descriptions': [{'description': 'Test upload of a simple galaxy image classifier',
#      'descriptionType': 'Abstract'}],
#    'identifier': {'identifier': '10.YET/UNASSIGNED', 'identifierType': 'DOI'},
#    'publicationYear': '2019',
#    'publisher': 'DLHub',
#    'resourceType': {'resourceTypeGeneral': 'InteractiveResource'},
#    'titles': [{'title': 'Galaxy Image Classifier'}]},
#   'dlhub': {'domains': ['astronomy'],
#    'ecr_uri': '039706667969.dkr.ecr.us-east-1.amazonaws.com/7b8f5273-2e1c-4836-b778-30efce4cf912',
#    'files': {'other': ['repo2docker/environment.yml',
#      'app.py',
#      'model/retrained_labels.txt',
#      'model/retrained_graph.pb']},
# ...

# %% [markdown]
# # Get Info on a Specific Servable

# %%
dl.search_by_servable("mschwarting_anl/BlurryBrain")
# Out:
# [{'datacite': {'creators': [{'affiliations': 'Argonne National Laboratory',
#      'familyName': 'Schwarting',
#      'givenName': 'Marcus'}],
#    'descriptions': [{'description': 'A function to determine blurry or clear SEM images.',
#      'descriptionType': 'Abstract'}],
#    'identifier': {'identifier': '10.YET/UNASSIGNED', 'identifierType': 'DOI'},
#    'publicationYear': '2019',
#    'publisher': 'DLHub',
#    'relatedIdentifiers': [{'relatedIdentifier': 'globus:1AZZVf9LBOLwY',
#      'relatedIdentifierType': 'Globus',
#      'relationType': 'IsDescribedBy'}],
#    'resourceType': {'resourceTypeGeneral': 'InteractiveResource'},
#    'titles': [{'title': 'Brain Image Blurriness Function'}]},
#   'dlhub': {'build_location': '/mnt/dlhub_ingest/9c1b435e-3e75-4376-ad5b-88317705afea-1564177444',
#    'domains': ['general', 'test'],
#    'ecr_arn': 'arn:aws:ecr:us-east-1:039706667969:repository/9c1b435e-3e75-4376-ad5b-88317705afea',
# ...

# %% [markdown]
# # Get Servable Metadata for All Servables

# %%
dl.get_servables()
# Out:
# [{'datacite': {'creators': [{'affiliations': 'University of Chicago',
#      'familyName': 'Koripelly',
#      'givenName': 'Aarthi'}],
#    'descriptions': [{'description': 'A function and CNN model to predict if SEM image is focused or blurry.',
#      'descriptionType': 'Abstract'}],
#    'identifier': {'identifier': '10.YET/UNASSIGNED', 'identifierType': 'DOI'},
#    'publicationYear': '2019',
#    'publisher': 'DLHub',
#    'relatedIdentifiers': [{'relatedIdentifier': 'globus:7WKVDWQfOB7D',
#      'relatedIdentifierType': 'Globus',
#      'relationType': 'IsDescribedBy'}],
#    'resourceType': {'resourceTypeGeneral': 'InteractiveResource'},
#    'titles': [{'title': 'SEM_CNN_Model'}]},
#   'dlhub': {'build_location': '/mnt/dlhub_ingest/d400a239-c252-4fec-bf17-a9ded50729ba-1565109436',
#    'domains': ['general', 'machinelearning'],
#    'ecr_arn': 'arn:aws:ecr:us-east-1:039706667969:repository/d400a239-c252-4fec-bf17-a9ded50729ba',
# ...

# %%
dl.search_by_authors(["Blaiszik"])
# Out:
# [{'datacite': {'creators': [{'affiliations': ['Argonne National Laboratory'],
#      'familyName': 'Ward',
#      'givenName': 'Logan'},
#     {'affiliations': ['Argonne National Laboratory'],
#      'familyName': 'Blaiszik',
#      'givenName': 'Ben'},
#     {'affiliations': ['Argonne National Laboratory'],
#      'familyName': 'Foster',
#      'givenName': 'Ian'},
#     {'affiliations': ['Argonne National Laboratory'],
#      'familyName': 'Assary',
#      'givenName': 'Rajeev'},
#     {'affiliations': ['Argonne National Laboratory'],
#      'familyName': 'Naranayan',
#      'givenName': 'Badri'},
#     {'affiliations': ['Argonne National Laboratory'],
#      'familyName': 'Curtis',
#      'givenName': 'Larry'}],
# ...
